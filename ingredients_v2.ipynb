# %% [markdown]
# ## v2
# #### v2 version converts all the upper cases to lower case. And also apply "Porter Stemmer" to the data.
# ##### It'll output the result as ingredients_v2.csvfile

# %%
import numpy as np
import pandas as pd
from nltk.stem import PorterStemmer

# %%
df=pd.read_csv('/Users/dobrien/Downloads/recipes.csv')  
df=df.groupby('recipe')['ingredient'].agg(list).reset_index(name='ingredient')
#ing = all ingredients used in recipes one by one. Ingredients are not unique in this variable. As you can see we have 655913 rows
ing=df.explode('ingredient')
ing
# Out:
#                                   recipe        ingredient
# 0                 1-2-3-cherry-poke-cake              cake
# 0                 1-2-3-cherry-poke-cake             water
# 0                 1-2-3-cherry-poke-cake   Whipped Topping
# 0                 1-2-3-cherry-poke-cake           Gelatin
# 0                 1-2-3-cherry-poke-cake         Chocolate
# ...                                  ...               ...
# 77038  zydeco-stomp-cajun-shrimp-alfredo   Parmesan cheese
# 77038  zydeco-stomp-cajun-shrimp-alfredo            shrimp
# 77038  zydeco-stomp-cajun-shrimp-alfredo            garlic
# 77038  zydeco-stomp-cajun-shrimp-alfredo           parsley
# 77038  zydeco-stomp-cajun-shrimp-alfredo  fettuccine pasta
#
# [655913 rows x 2 columns]

# %%
ing['ingredient']=ing['ingredient'].str.lower()   #all ingredients are converted to lower case. It decreased from 6842 to 6271.    

#now the stemmer will be applied and unique ingredients woill be decreased 6271 to 5927.  
stemmer = PorterStemmer()

# define a lambda function to apply the stemmer to each element in the column
stem_function = lambda x: stemmer.stem(x)

# apply the lambda function to the 'Ingredients' column using the apply() method
ing['Stemmed'] = ing['ingredient'].apply(stem_function)

# print out the resulting DataFrame
ing
# Out:
#                                   recipe        ingredient           Stemmed
# 0                 1-2-3-cherry-poke-cake              cake              cake
# 0                 1-2-3-cherry-poke-cake             water             water
# 0                 1-2-3-cherry-poke-cake   whipped topping       whipped top
# 0                 1-2-3-cherry-poke-cake           gelatin           gelatin
# 0                 1-2-3-cherry-poke-cake         chocolate            chocol
# ...                                  ...               ...               ...
# 77038  zydeco-stomp-cajun-shrimp-alfredo   parmesan cheese    parmesan chees
# 77038  zydeco-stomp-cajun-shrimp-alfredo            shrimp            shrimp
# 77038  zydeco-stomp-cajun-shrimp-alfredo            garlic            garlic
# 77038  zydeco-stomp-cajun-shrimp-alfredo           parsley           parsley
# 77038  zydeco-stomp-cajun-shrimp-alfredo  fettuccine pasta  fettuccine pasta
#
# [655913 rows x 3 columns]

# %%
ing['Stemmed'].nunique() #we have 6271 unique ingredient(string)
# Out:
# 5927

# %%
#we will have two list with alligned indexes. 
#the list called 'uniques' will have unique ingredients names after applying NLP methods.
#the list called 'num' will have the number of the corresponding ingredients used in the recipes.
#this part of code will take around 2 mins to compile

uniques=[] 
num=[0]*ing['Stemmed'].nunique()  #the number of unique ingredient.(5927) Initial amount will be zero for all of them

for i in range(len(ing)): 
    if ing.iloc[i][2] in uniques:
        num[uniques.index(ing.iloc[i][2])] +=1
    else:
        uniques.append(ing.iloc[i][2])
        num[uniques.index(ing.iloc[i][2])] +=1
        

len(uniques)
# Out:
# 5927

# %%
#Now we create a dataframe called dfzips and sort all the ingredients in descending order again after nlp methods.
dfzips=pd.DataFrame(list(zip(uniques,num)),columns=['Ingredient','Number of Usage'])
dfzips=dfzips.sort_values('Number of Usage', ascending=False).reset_index(drop=True)
dfzips
# Out:
#            Ingredient  Number of Usage
# 0                salt            31117
# 1               onion            23295
# 2                 egg            21607
# 3              garlic            21343
# 4              butter            20551
# ...               ...              ...
# 5922        rice flak                1
# 5923      rice starch                1
# 5924     banana flour                1
# 5925  organic shorten                1
# 5926        mexican 4                1
#
# [5927 rows x 2 columns]

# %%
dfzips.to_csv('ingredients_v2.csv',index=True)

# %%
df_recipes=pd.read_csv('./recipes_v3.csv')  
df_ingredients=pd.read_csv('./ingredients_v3.csv')  

recipe_list = df_recipes.to_numpy()
ingredient_list = df_ingredients.to_numpy()

# derives ingredients from list with less than 25 occurences
less_than_25_occurences = [x[1] for x in ingredient_list if int(x[2]) <= 25]

# remove ingredients that appear less than 25 times
refined_ingredient_list = [x for x in ingredient_list if int(x[2]) > 25]

# remove all recipes that have ingredients that appear less than 25 times
refined_recipe_list = [x for x in recipe_list if x[2] not in less_than_25_occurences]

# %%
# derive recipes and their ingredient counts
recipe_map = {}
for recipe in refined_recipe_list:
    try:
        if recipe_map[recipe[1]]:
            recipe_map[recipe[1]] = recipe_map[recipe[1]] + 1
    except:
        recipe_map[recipe[1]] = 1

# derive list of all recipes with less than 5 ingredients
recipes_with_less_than_5_ingredients = [x for x in recipe_map if recipe_map[x] < 5]

# derive only recipes with > 5 ingredients
final_refined_recipe_list = [x for x in refined_recipe_list if x[1] not in recipes_with_less_than_5_ingredients]

# %%
df_out_ingredients = pd.DataFrame(refined_ingredient_list, columns = ['','Ingredient','Number of Usage'])
df_out_recipes = pd.DataFrame(final_refined_recipe_list, columns = ['','Recipe','Ingredient'])


df_out_ingredients.to_csv('ingredients_v4.csv',index=True)
df_out_recipes.to_csv('recipes_v4.csv',index=True)

# %%
refined_recipe_list
# recipe_map = {}
# for recipe in final_refined_recipe_list:
#     try:
#         if recipe_map[recipe[1]]:
#             recipe_map[recipe[1]] = recipe_map[recipe[1]] + 1
#     except:
#         recipe_map[recipe[1]] = 1

# # for recipe in recipe_map:
# #     print(recipe_map[recipe] < 5)


# for recipe in recipes_with_less_than_5_ingredients:
#     print(recipe_map[recipe])
# Out:
# [array([0, '1-2-3-cherry-poke-cake', 'cake'], dtype=object),
#  array([0, '1-2-3-cherry-poke-cake', 'water'], dtype=object),
#  array([0, '1-2-3-cherry-poke-cake', 'whipped top'], dtype=object),
#  array([0, '1-2-3-cherry-poke-cake', 'gelatin'], dtype=object),
#  array([0, '1-2-3-cherry-poke-cake', 'chocol'], dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'oat'], dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'water'], dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'honey'], dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'blueberri'], dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'protein powd'],
#        dtype=object),
#  array([1, '1-2-3-complete-breakfast-smoothie', 'yogurt'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'worcestershire sauc'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'olive oil'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'parsley'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'tomato'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'sausag'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'chicken broth'], dtype=object),
#  array([2, '1-2-3-jambalaya', 'pepper sauc'], dtype=object),
#  array([3, '1-2-3-lemon-icebox-pie', 'lemon'], dtype=object),
#  array([3, '1-2-3-lemon-icebox-pie', 'milk'], dtype=object),
#  array([3, '1-2-3-lemon-icebox-pie', 'graham cracker crust'], dtype=object),
#  array([3, '1-2-3-lemon-icebox-pie', 'egg'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'chees'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'olive oil'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'spice'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'chicken'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'all purpose flour'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'sugar'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'salt'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'spaghetti sauc'], dtype=object),
#  array([4, '1-dish-chicken-parmesan', 'cooking spray'], dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'all purpose flour'],
#        dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'cooking spray'],
#        dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'mozzarella chees'],
#        dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'pizza sauc'],
#        dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'salt'], dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'sugar'], dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'pepperoni'], dtype=object),
#  array([5, '1-dish-pepperoni-cheese-pizza-bake', 'olive oil'], dtype=object),
#  array([6, '1-dish-taco-bake', 'cooking spray'], dtype=object),
#  array([6, '1-dish-taco-bake', 'chees'], dtype=object),
#  array([6, '1-dish-taco-bake', 'sugar'], dtype=object),
#  array([6, '1-dish-taco-bake', 'flour'], dtype=object),
#  array([6, '1-dish-taco-bake', 'corn chip'], dtype=object),
#  array([6, '1-dish-taco-bake', 'corn oil'], dtype=object),
#  array([6, '1-dish-taco-bake', 'egg'], dtype=object),
#  array([6, '1-dish-taco-bake', 'beef'], dtype=object),
#  array([6, '1-dish-taco-bake', 'all purpose flour'], dtype=object),
#  array([6, '1-dish-taco-bake', 'salsa'], dtype=object),
#  array([6, '1-dish-taco-bake', 'salt'], dtype=object),
#  array([6, '1-dish-taco-bake', 'taco season'], dtype=object),
#  array([7, '1-pea-salad-most-requested', 'onion'], dtype=object),
#  array([7, '1-pea-salad-most-requested', 'black pepp'], dtype=object),
#  array([7, '1-pea-salad-most-requested', 'petite pea'], dtype=object),
#  array([7, '1-pea-salad-most-requested', 'mayonnais'], dtype=object),
#  array([7, '1-pea-salad-most-requested', 'almond'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'bay leaf'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'chicken broth'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'carrot'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'canola oil'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'black pepp'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'parsley'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'herb'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'celeri'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'bean'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'cilantro'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'dry red win'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'kidney bean'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'tomato'], dtype=object),
#  array([8, '1-pot-3-bean-chicken-stew', 'onion'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'all purpose flour'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'brown sugar'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'walnut'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'cinnamon'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'butter'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'pumpkin se'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'ginger'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'salt'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'egg'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'oat'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'apple butt'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'baking powd'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'vanilla extract'], dtype=object),
#  array([9, '1-pumpkin-spice-cookies', 'nutmeg'], dtype=object),
#  array([10, '1-step-chipotle-hummus', 'hummu'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'vanilla extract'],
#        dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'egg'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'all purpose flour'],
#        dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'salt'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'milk'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'white sugar'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'olive oil'], dtype=object),
#  array([11, '10-minute-chocolate-mug-cake', 'cocoa powd'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'olive oil'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'mushroom'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'egg'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'spaghetti'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'garlic'], dtype=object),
#  array([12, '10-minute-mushroom-carbonara', 'parmesan chees'], dtype=object),
#  array([13, '10-minute-rice-cakes', 'basil'], dtype=object),
#  array([13, '10-minute-rice-cakes', 'milk'], dtype=object),
#  array([13, '10-minute-rice-cakes', 'white bread'], dtype=object),
#  array([13, '10-minute-rice-cakes', 'butter'], dtype=object),
#  array([13, '10-minute-rice-cakes', 'egg'], dtype=object),
#  array([14, '10-minute-tomato-basil-salad', 'tomato'], dtype=object),
#  array([14, '10-minute-tomato-basil-salad', 'olive oil'], dtype=object),
#  array([14, '10-minute-tomato-basil-salad', 'white vinegar'], dtype=object),
#  array([14, '10-minute-tomato-basil-salad', 'basil'], dtype=object),
#  array([15, '10-pound-cheesecake', 'cream chees'], dtype=object),
#  array([15, '10-pound-cheesecake', 'whipped top'], dtype=object),
#  array([15, '10-pound-cheesecake', 'vanilla extract'], dtype=object),
#  array([15, '10-pound-cheesecake', 'white sugar'], dtype=object),
#  array([15, '10-pound-cheesecake', 'lemon juic'], dtype=object),
#  array([15, '10-pound-cheesecake', 'graham cracker crumb'], dtype=object),
#  array([15, '10-pound-cheesecake', 'milk'], dtype=object),
#  array([15, '10-pound-cheesecake', 'butter'], dtype=object),
#  array([16, '100-fruit-cake', 'cantaloup'], dtype=object),
#  array([16, '100-fruit-cake', 'watermelon'], dtype=object),
#  array([16, '100-fruit-cake', 'strawberri'], dtype=object),
#  array([16, '100-fruit-cake', 'pineappl'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'honey'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'whole wheat flour'],
#        dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'coconut milk'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'oat'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'wheat gluten'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'yeast'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'quinoa'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'water'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'sesame oil'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'sunflower se'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'salt'], dtype=object),
#  array([17, '100-percent-whole-wheat-bread', 'flax se'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'banana'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'ginger'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'whole wheat flour'],
#        dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'cinnamon'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'nutmeg'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'salt'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'baking powd'],
#        dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'vegetable oil'],
#        dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'baking soda'],
#        dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'egg'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'appl'], dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'brown sugar'],
#        dtype=object),
#  array([18, '100-whole-wheat-harvest-pancakes', 'vanilla extract'],
#        dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'salt'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'vegetable oil'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'egg'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'white sugar'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'baking powd'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'baking soda'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'whole wheat flour'], dtype=object),
#  array([19, '100-whole-wheat-pancakes', 'buttermilk'], dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread',
#         'whole wheat flour'], dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'baking soda'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'water'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'dry yeast'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'baking powd'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'brown sugar'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread',
#         'wheat gluten'], dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'salt'],
#        dtype=object),
#  array([20, '100-whole-wheat-peanut-butter-and-jelly-bread', 'butter'],
#        dtype=object),
#  array([21, '1094', 'butter'], dtype=object),
#  array([21, '1094', 'egg'], dtype=object),
#  array([22, '11-can-chili', 'tomato'], dtype=object),
#  array([22, '11-can-chili', 'bean'], dtype=object),
#  array([22, '11-can-chili', 'kidney bean'], dtype=object),
#  array([22, '11-can-chili', 'black pepp'], dtype=object),
#  array([22, '11-can-chili', 'beef'], dtype=object),
#  array([22, '11-can-chili', 'onion'], dtype=object),
#  array([22, '11-can-chili', 'garlic'], dtype=object),
#  array([23, '12-second-coleslaw', 'white vinegar'], dtype=object),
#  array([23, '12-second-coleslaw', 'salt'], dtype=object),
#  array([23, '12-second-coleslaw', 'cabbag'], dtype=object),
#  array([23, '12-second-coleslaw', 'soy sauc'], dtype=object),
#  array([24, '120-calorie-peach-pies', 'pie crust'], dtype=object),
#  array([24, '120-calorie-peach-pies', 'white sugar'], dtype=object),
#  array([24, '120-calorie-peach-pies', 'cinnamon'], dtype=object),
#  array([24, '120-calorie-peach-pies', 'peach'], dtype=object),
#  array([25, '121-whipped-cream', 'sugar'], dtype=object),
#  array([25, '121-whipped-cream', 'heavy whipping cream'], dtype=object),
#  array([25, '121-whipped-cream', 'vanilla extract'], dtype=object),
#  array([26, '123-green-tea-ice-cream', 'creami'], dtype=object),
#  array([26, '123-green-tea-ice-cream', 'green tea powd'], dtype=object),
#  array([27, '123-mocha-2-go', 'chocolate drink'], dtype=object),
#  array([27, '123-mocha-2-go', 'coffee granul'], dtype=object),
#  array([27, '123-mocha-2-go', 'cinnamon'], dtype=object),
#  array([27, '123-mocha-2-go', 'milk powd'], dtype=object),
#  array([28, '1234-taiwanese-spare-ribs', 'white vinegar'], dtype=object),
#  array([28, '1234-taiwanese-spare-ribs', 'tomato'], dtype=object),
#  array([28, '1234-taiwanese-spare-ribs', 'white sugar'], dtype=object),
#  array([28, '1234-taiwanese-spare-ribs', 'soy sauc'], dtype=object),
#  array([29, '12th-man-hattan', 'cherri'], dtype=object),
#  array([29, '12th-man-hattan', 'bitter'], dtype=object),
#  array([29, '12th-man-hattan', 'orang'], dtype=object),
#  array([30, '14-hands-frose', 'lemon'], dtype=object),
#  array([30, '14-hands-frose', 'strawberri'], dtype=object),
#  array([30, '14-hands-frose', 'agave nectar'], dtype=object),
#  array([31, '15-minute-baked-zucchini-fries', 'parmesan chees'],
#        dtype=object),
#  array([31, '15-minute-baked-zucchini-fries', 'zucchini'], dtype=object),
#  array([31, '15-minute-baked-zucchini-fries', 'bread crumb'], dtype=object),
#  array([31, '15-minute-baked-zucchini-fries', 'spread'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'water'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'cheddar chees'],
#        dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'white bread'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'beef'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'salsa'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'tomato'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'taco season'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'lettuc'], dtype=object),
#  array([32, '15-minute-dinner-nachos-supreme', 'tortilla chip'],
#        dtype=object),
#  array([34, '15-minute-herbed-chicken', 'milk'], dtype=object),
#  array([34, '15-minute-herbed-chicken', 'chicken broth'], dtype=object),
#  array([34, '15-minute-herbed-chicken', 'vegetable oil'], dtype=object),
#  array([34, '15-minute-herbed-chicken', 'chicken'], dtype=object),
#  array([34, '15-minute-herbed-chicken', 'rice'], dtype=object),
#  array([35, '15-minute-pickled-beets-kitchen-hack-version', 'salt'],
#        dtype=object),
#  array([35, '15-minute-pickled-beets-kitchen-hack-version', 'beet'],
#        dtype=object),
#  array([35, '15-minute-pickled-beets-kitchen-hack-version', 'clove'],
#        dtype=object),
#  array([35, '15-minute-pickled-beets-kitchen-hack-version',
#         'white vinegar'], dtype=object),
#  array([35, '15-minute-pickled-beets-kitchen-hack-version', 'white sugar'],
#        dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'all purpose flour'],
#        dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'olive oil'], dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'liquid smok'], dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'black pepp'], dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'water'], dtype=object),
#  array([36, '15-minute-vegetarian-gravy', 'milk'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'salt'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'parmesan chees'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'olive oil'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'nutmeg'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'basil leav'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'garlic'], dtype=object),
#  array([37, '15-year-old-pesto-sauce', 'peanut'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'pie crust'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'white sugar'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'heavy whipping cream'],
#        dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'strawberri'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'cream chees'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'cornstarch'], dtype=object),
#  array([38, '1970s-french-strawberry-pie', 'vanilla extract'], dtype=object),
#  array([39, '2-bean-chili', 'tomato'], dtype=object),
#  array([39, '2-bean-chili', 'kidney bean'], dtype=object),
#  array([39, '2-bean-chili', 'onion'], dtype=object),
#  array([39, '2-bean-chili', 'bean'], dtype=object),
#  array([39, '2-bean-chili', 'cheddar chees'], dtype=object),
#  array([39, '2-bean-chili', 'black pepp'], dtype=object),
#  array([39, '2-bean-chili', 'sour cream'], dtype=object),
#  array([39, '2-bean-chili', 'beef'], dtype=object),
#  array([39, '2-bean-chili', 'chili powd'], dtype=object),
#  array([39, '2-bean-chili', 'green pepp'], dtype=object),
#  array([40, '2-ingredient-coconut-ice-cream', 'milk'], dtype=object),
#  array([40, '2-ingredient-coconut-ice-cream', 'coconut milk'], dtype=object),
#  array([41, '2-ingredient-dog-treats', 'whole wheat flour'], dtype=object),
#  array([41, '2-ingredient-dog-treats', 'carrot'], dtype=object),
#  array([42, '2-ingredient-fresas-con-leche', 'strawberri'], dtype=object),
#  array([43, '2-ingredient-ice-cream', 'heavy whipping cream'], dtype=object),
#  array([43, '2-ingredient-ice-cream', 'milk'], dtype=object),
#  array([44, '2-ingredient-instant-pudding-blender-ice-cream',
#         'chocolate pud'], dtype=object),
#  array([44, '2-ingredient-instant-pudding-blender-ice-cream', 'milk'],
#        dtype=object),
#  array([45, '2-ingredient-peanut-butter-fudge', 'butter'], dtype=object),
#  array([46, '2-ingredient-pineapple-angel-food-cake', 'cake'], dtype=object),
#  array([46, '2-ingredient-pineapple-angel-food-cake', 'pineappl'],
#        dtype=object),
#  array([47, '2-ingredient-pineapple-whip', 'pineappl'], dtype=object),
#  array([47, '2-ingredient-pineapple-whip', 'water'], dtype=object),
#  array([48, '2-ingredient-pumpkin-cookies', 'spice cak'], dtype=object),
#  array([48, '2-ingredient-pumpkin-cookies', 'pumpkin se'], dtype=object),
#  array([49, '2-ingredient-rotel-bean-dip', 'tomato'], dtype=object),
#  array([49, '2-ingredient-rotel-bean-dip', 'black pepp'], dtype=object),
#  array([50, '2-ingredient-strawberry-sorbet', 'milk'], dtype=object),
#  array([51, '2-ingredient-wheat-free-banana-pancakes-paleo', 'banana'],
#        dtype=object),
#  array([51, '2-ingredient-wheat-free-banana-pancakes-paleo', 'butter'],
#        dtype=object),
#  array([51, '2-ingredient-wheat-free-banana-pancakes-paleo', 'egg'],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'vegetable oil'],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'water'], dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'banana'],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'sugar'], dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'egg'], dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'banana bread'],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'milk'], dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', "devil's food"],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'chocolate pud'],
#        dtype=object),
#  array([52, '2-layer-chocolate-banana-pudding-cake', 'chocol'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'cream chees'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'white sugar'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'egg'], dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'vanilla extract'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'corn syrup'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'butter'],
#        dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'pecan'], dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'salt'], dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'water'], dtype=object),
#  array([53, '2-layer-rum-pecan-pie-with-cheesecake', 'pastri'],
#        dtype=object),
#  array([54, '2-minute-cheese-quesadillas', 'cheddar chees'], dtype=object),
#  array([54, '2-minute-cheese-quesadillas', 'flour tortilla'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'onion'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'black pepp'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'kernel corn'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'salsa'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'avocado'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'jalapeno'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'cumin'], dtype=object),
#  array([55, '2-minute-corn-salsa', 'lime'], dtype=object),
#  array([56, '2-step-chocolate-taco', 'chocolate chip'], dtype=object),
#  array([56, '2-step-chocolate-taco', 'flour tortilla'], dtype=object),
#  array([57, '2-step-creamy-chicken-and-pasta', 'water'], dtype=object),
#  array([57, '2-step-creamy-chicken-and-pasta', 'chicken broth'],
#        dtype=object),
#  array([57, '2-step-creamy-chicken-and-pasta', 'vegetable oil'],
#        dtype=object),
#  array([58, '2-step-inside-out-chicken-pot-pie', 'chicken'], dtype=object),
#  array([58, '2-step-inside-out-chicken-pot-pie', 'chicken broth'],
#        dtype=object),
#  array([58, '2-step-inside-out-chicken-pot-pie', 'vegetable oil'],
#        dtype=object),
#  array([59, '2-step-skillet-chicken-broccoli-divan', 'butter'],
#        dtype=object),
#  array([59, '2-step-skillet-chicken-broccoli-divan', 'chicken broth'],
#        dtype=object),
#  array([59, '2-step-skillet-chicken-broccoli-divan', 'chicken'],
#        dtype=object),
#  array([59, '2-step-skillet-chicken-broccoli-divan', 'milk'], dtype=object),
#  array([59, '2-step-skillet-chicken-broccoli-divan', 'cheddar chees'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'water'], dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'rice'], dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'onion'], dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'olive oil'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'tomato'], dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'parmesan chees'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'basil leav'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'baked chicken tend'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'red pepp'],
#        dtype=object),
#  array([60, '20-minute-basil-chicken-tomato-rice', 'garlic'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'honey'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'shrimp'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'cumin'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'cilantro'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'salt'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'garlic'], dtype=object),
#  array([61, '20-minute-chipotle-shrimp', 'lemon juic'], dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'italian season'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'parmesan chees'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'water'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'broccoli'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'butter'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'potato gnocchi'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'black pepp'],
#        dtype=object),
#  array([62, '20-minute-sausage-broccoli-gnocchi-alfredo', 'garlic'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'lime'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'orang'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'paprika'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'garlic'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'black pepp'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'shrimp'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'flour tortilla'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'onion powd'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'cooking spray'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'chili powd'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'cumin'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'salt'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'olive oil'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'onion'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'cilantro'],
#        dtype=object),
#  array([63, '20-minute-shrimp-fajitas-sheet-pan-dinner', 'avocado'],
#        dtype=object),
#  array([64, '20-minute-skillet-salmon', 'white bread'], dtype=object),
#  array([64, '20-minute-skillet-salmon', 'milk'], dtype=object),
#  array([64, '20-minute-skillet-salmon', 'cucumb'], dtype=object),
#  array([64, '20-minute-skillet-salmon', 'cream chees'], dtype=object),
#  array([64, '20-minute-skillet-salmon', 'salmon'], dtype=object),
#  array([64, '20-minute-skillet-salmon', 'dill'], dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese', 'spinach'],
#        dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese',
#         'cheddar chees'], dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese',
#         'artichoke heart'], dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese', 'water'],
#        dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese',
#         'unsalted butt'], dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese', 'salt'],
#        dtype=object),
#  array([65, '20-minute-spinach-and-artichoke-macaroni-cheese',
#         'bread crumb'], dtype=object),
#  array([66, '20-second-salad', 'onion'], dtype=object),
#  array([66, '20-second-salad', 'mustard powd'], dtype=object),
#  array([66, '20-second-salad', 'salt'], dtype=object),
#  array([66, '20-second-salad', 'green pepp'], dtype=object),
#  array([66, '20-second-salad', 'white vinegar'], dtype=object),
#  array([66, '20-second-salad', 'poppy se'], dtype=object),
#  array([66, '20-second-salad', 'peanut'], dtype=object),
#  array([66, '20-second-salad', 'white sugar'], dtype=object),
#  array([66, '20-second-salad', 'vegetable oil'], dtype=object),
#  array([67, '23600', 'egg'], dtype=object),
#  array([67, '23600', 'butter'], dtype=object),
#  array([68, '24-hour-ham-casserole', 'macaroni'], dtype=object),
#  array([68, '24-hour-ham-casserole', 'egg'], dtype=object),
#  array([68, '24-hour-ham-casserole', 'ham steak'], dtype=object),
#  array([68, '24-hour-ham-casserole', 'cheddar chees'], dtype=object),
#  array([69, '24-hour-salad', 'heavy cream'], dtype=object),
#  array([69, '24-hour-salad', 'butter'], dtype=object),
#  array([69, '24-hour-salad', 'orang'], dtype=object),
#  array([69, '24-hour-salad', 'marshmallow'], dtype=object),
#  array([69, '24-hour-salad', 'egg'], dtype=object),
#  array([69, '24-hour-salad', 'salt'], dtype=object),
#  array([69, '24-hour-salad', 'pineapple tidbit'], dtype=object),
#  array([69, '24-hour-salad', 'white sugar'], dtype=object),
#  array([69, '24-hour-salad', 'white vinegar'], dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'paprika'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'almond'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'vegetable oil'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'orang'], dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'cilantro'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'olive oil'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'mushroom'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'parmesan chees'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'carrot'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'chickpea'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'onion'], dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'zucchini'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'salt'], dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'tomato'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'couscou'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'yellow squash'],
#        dtype=object),
#  array([70, '25-minute-tunisian-vegetable-couscous', 'cardamom'],
#        dtype=object),
#  array([71, '3-2-1-peanut-butter-fudge', "confectioners' sugar"],
#        dtype=object),
#  array([71, '3-2-1-peanut-butter-fudge', 'butter'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'lemon juic'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'salt'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'brown sugar'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'wood chip'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'mustard'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'pork sparerib'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'aluminum foil'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'chili powd'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'paprika'], dtype=object),
#  array([72, '3-2-1-smoked-bbq-ribs', 'butter'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'tomato'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'onion powd'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'oregano'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'eggplant'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'salt'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'basil'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'romano chees'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'olive oil'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'garlic'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'onion'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'mozzarella chees'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'spinach'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'egg'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'ricotta chees'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'carrot'], dtype=object),
#  array([73, '3-cheese-eggplant-lasagna', 'canola oil'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'cream chees'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'salsa'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'cheddar chees'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'flour tortilla'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'chees'], dtype=object),
#  array([74, '3-cheese-enchiladas', 'onion'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'tomato'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'spaghetti squash'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'mushroom'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'butter'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'mozzarella chees'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'parmesan chees'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'garlic'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'cheddar chees'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'basil'], dtype=object),
#  array([75, '3-cheese-spaghetti-squash', 'balsamic vinegar'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'garlic'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'flour tortilla'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'black pepp'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'mozzarella chees'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'salt'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'basil'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'parmesan chees'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'cheddar chees'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'rosemari'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'tomato'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'oregano'], dtype=object),
#  array([76, '3-cheese-tortilla-pizza', 'salami'], dtype=object),
#  array([77, '3-ingredient-baked-bbq-chicken-wings', 'chicken'],
#        dtype=object),
#  array([77, '3-ingredient-baked-bbq-chicken-wings', 'barbeque sauc'],
#        dtype=object),
#  array([78, '3-ingredient-cake-mix-cobbler', 'cake'], dtype=object),
#  array([78, '3-ingredient-cake-mix-cobbler', 'butter'], dtype=object),
#  array([78, '3-ingredient-cake-mix-cobbler', 'peach'], dtype=object),
#  array([79, '3-ingredient-cheesecake', 'chocol'], dtype=object),
#  array([79, '3-ingredient-cheesecake', 'cream chees'], dtype=object),
#  array([79, '3-ingredient-cheesecake', 'egg'], dtype=object),
#  array([80, '3-ingredient-cookies', 'chocolate chip'], dtype=object),
#  array([80, '3-ingredient-cookies', 'banana'], dtype=object),
#  array([80, '3-ingredient-cookies', 'oat'], dtype=object),
#  array([81, '3-ingredient-frozen-hot-chocolate', 'milk'], dtype=object),
#  array([81, '3-ingredient-frozen-hot-chocolate', 'cocoa'], dtype=object),
#  array([82, '3-ingredient-lemon-scones', 'cooking spray'], dtype=object),
#  array([82, '3-ingredient-lemon-scones', 'heavy cream'], dtype=object),
#  array([82, '3-ingredient-lemon-scones', 'flour'], dtype=object),
#  array([83, '3-ingredient-oreo-bites', 'almond m'], dtype=object),
#  array([83, '3-ingredient-oreo-bites', 'cream chees'], dtype=object),
#  array([83, '3-ingredient-oreo-bites', 'cooki'], dtype=object),
#  array([84, '3-ingredient-pancakes', 'baking powd'], dtype=object),
#  array([84, '3-ingredient-pancakes', 'banana'], dtype=object),
#  array([84, '3-ingredient-pancakes', 'butter'], dtype=object),
#  array([84, '3-ingredient-pancakes', 'egg'], dtype=object),
#  array([84, '3-ingredient-pancakes', 'cinnamon'], dtype=object),
#  array([85, '3-ingredient-parmesan-cookies', 'all purpose flour'],
#        dtype=object),
#  array([85, '3-ingredient-parmesan-cookies', 'butter'], dtype=object),
#  array([85, '3-ingredient-parmesan-cookies', 'parmesan chees'],
#        dtype=object),
#  array([86, '3-ingredient-peanut-butter-cookies', 'white sugar'],
#        dtype=object),
#  array([86, '3-ingredient-peanut-butter-cookies', 'egg'], dtype=object),
#  array([86, '3-ingredient-peanut-butter-cookies', 'butter'], dtype=object),
#  array([87, '3-ingredient-pulled-pork-barbeque', 'barbeque sauc'],
#        dtype=object),
#  array([87, '3-ingredient-pulled-pork-barbeque', 'pork loin'], dtype=object),
#  array([87, '3-ingredient-pulled-pork-barbeque', 'onion soup'],
#        dtype=object),
#  array([87, '3-ingredient-pulled-pork-barbeque', 'pork'], dtype=object),
#  array([88, '3-ingredient-shortbread-cookies', 'cherri'], dtype=object),
#  array([88, '3-ingredient-shortbread-cookies', "confectioners' sugar"],
#        dtype=object),
#  array([88, '3-ingredient-shortbread-cookies', 'all purpose flour'],
#        dtype=object),
#  array([88, '3-ingredient-shortbread-cookies', 'butter'], dtype=object),
#  array([89, '3-ingredient-slow-cooker-sweetened-condensed-milk', 'milk'],
#        dtype=object),
#  array([89, '3-ingredient-slow-cooker-sweetened-condensed-milk',
#         'vanilla extract'], dtype=object),
#  array([89, '3-ingredient-slow-cooker-sweetened-condensed-milk',
#         'white sugar'], dtype=object),
#  array([89, '3-ingredient-slow-cooker-sweetened-condensed-milk', 'butter'],
#        dtype=object),
#  array([90, '3-ingredient-swedish-meatballs', 'sour cream'], dtype=object),
#  array([91, '3-ingredient-tastes-just-like-sangria', 'red win'],
#        dtype=object),
#  array([91, '3-ingredient-tastes-just-like-sangria', 'ginger al'],
#        dtype=object),
#  array([91, '3-ingredient-tastes-just-like-sangria', 'lime'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'cinnamon'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'pineappl'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'cream chees'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'lemon juic'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'carrot'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'vanilla extract'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'all purpose flour'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting', 'egg'],
#        dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting', 'salt'],
#        dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'butter'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'white sugar'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'corn oil'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'baking soda'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         'walnut'], dtype=object),
#  array([92, '3-layer-carrot-cake-with-lemon-buttercream-frosting',
#         "confectioners' sugar"], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'milk'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'vanilla extract'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'baking powd'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'cream chees'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'all purpose flour'],
#        dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'heavy whipping cream'],
#        dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'butter'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'white sugar'], dtype=object),
#  array([93, '3-milk-cake-or-tres-leches', 'egg'], dtype=object),
#  array([94, '3-minute-fudge', 'chocol'], dtype=object),
#  array([94, '3-minute-fudge', 'milk'], dtype=object),
#  array([94, '3-minute-fudge', 'chocolate chip'], dtype=object),
#  array([95, '3-minute-mochaccino', 'coffee granul'], dtype=object),
#  array([95, '3-minute-mochaccino', 'chocolate syrup'], dtype=object),
#  array([95, '3-minute-mochaccino', 'whipped cream'], dtype=object),
#  array([95, '3-minute-mochaccino', 'white sugar'], dtype=object),
#  array([95, '3-minute-mochaccino', 'milk'], dtype=object),
#  array([95, '3-minute-mochaccino', 'cocoa powd'], dtype=object),
#  array([95, '3-minute-mochaccino', 'vanilla extract'], dtype=object),
#  array([96, '3-musketeers-trifle', 'cream chees'], dtype=object),
#  array([96, '3-musketeers-trifle', 'browni'], dtype=object),
#  array([96, '3-musketeers-trifle', 'vegetable oil'], dtype=object),
#  array([96, '3-musketeers-trifle', 'egg'], dtype=object),
#  array([96, '3-musketeers-trifle', 'heavy whipping cream'], dtype=object),
#  array([96, '3-musketeers-trifle', 'water'], dtype=object),
#  array([96, '3-musketeers-trifle', 'chocolate chip'], dtype=object),
#  array([97, '3-p-salad', 'pea'], dtype=object),
#  array([97, '3-p-salad', 'peanut'], dtype=object),
#  array([97, '3-p-salad', 'dill pickl'], dtype=object),
#  array([97, '3-p-salad', 'mayonnais'], dtype=object),
#  array([98, '3-step-butter-chicken', 'chicken'], dtype=object),
#  array([98, '3-step-butter-chicken', 'vegetable oil'], dtype=object),
#  array([98, '3-step-butter-chicken', 'water'], dtype=object),
#  array([98, '3-step-butter-chicken', 'chicken broth'], dtype=object),
#  array([99, '30-minute-almond-chicken-by-minute-rice', 'almond'],
#        dtype=object),
#  array([99, '30-minute-almond-chicken-by-minute-rice', 'italian dress'],
#        dtype=object),
#  array([99, '30-minute-almond-chicken-by-minute-rice', 'chicken broth'],
#        dtype=object),
#  array([99, '30-minute-almond-chicken-by-minute-rice', 'white bread'],
#        dtype=object),
#  array([99, '30-minute-almond-chicken-by-minute-rice', 'green pepp'],
#        dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'taco season'],
#        dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'chees'], dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'cilantro'],
#        dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'onion'], dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'salsa'], dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'olive oil'],
#        dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'chicken broth'],
#        dtype=object),
#  array([100, '30-minute-chicken-enchilada-skillet', 'flour tortilla'],
#        dtype=object),
#  array([101, '30-minute-chili-from-rotel', 'tomato'], dtype=object),
#  array([101, '30-minute-chili-from-rotel', 'water'], dtype=object),
#  array([101, '30-minute-chili-from-rotel', 'bean'], dtype=object),
#  array([101, '30-minute-chili-from-rotel', 'onion'], dtype=object),
#  array([101, '30-minute-chili-from-rotel', 'chili season'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'onion'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'beef broth'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'lemon juic'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'salt'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'beef'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'vegetable oil'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'cabbag'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'bacon'], dtype=object),
#  array([102, '30-minute-irish-skillet', 'browni'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'milk'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'garlic'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'potato'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'pizza dough'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'cheddar chees'],
#        dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'butter'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'olive oil'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'bacon'], dtype=object),
#  array([103, '30-minute-mashed-potato-pizza', 'mozzarella chees'],
#        dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'hoisin sauc'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'garlic'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'pork should'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'water'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'basmati ric'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'red bell pepp'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'oil'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'soy sauc'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'onion'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'edamam'], dtype=object),
#  array([104, '30-minute-pork-fried-rice', 'egg'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'potato'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'egg'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'salt'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'garlic'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'sausag'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'spinach leav'],
#        dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'chili powd'],
#        dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'black pepp'],
#        dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'olive oil'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'sour cream'],
#        dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'cilantro'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'onion'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'salsa'], dtype=object),
#  array([105, '30-minute-potato-breakfast-bowls', 'cotija chees'],
#        dtype=object),
#  array([106, '30-minute-white-bean-chili', 'bean'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'garlic'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'turkey breast'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'celeri'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'onion'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'cumin'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'chili powd'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'lima bean'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'bay leaf'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'basil'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'tomato'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'olive oil'], dtype=object),
#  array([106, '30-minute-white-bean-chili', 'water'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'onion'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'butter'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'bean'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'ketchup'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'bacon'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'mustard'], dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'worcestershire sauc'],
#        dtype=object),
#  array([107, '3bc-best-baked-bean-casserole', 'brown sugar'], dtype=object),
#  array([108, '4-bean-baked-beans', 'brown sugar'], dtype=object),
#  array([108, '4-bean-baked-beans', 'ketchup'], dtype=object),
#  array([108, '4-bean-baked-beans', 'lima bean'], dtype=object),
#  array([108, '4-bean-baked-beans', 'bacon'], dtype=object),
#  array([108, '4-bean-baked-beans', 'onion'], dtype=object),
#  array([108, '4-bean-baked-beans', 'garlic'], dtype=object),
#  array([108, '4-bean-baked-beans', 'butter'], dtype=object),
#  array([108, '4-bean-baked-beans', 'kidney bean'], dtype=object),
# ...
#  array([133, '4th-of-july-flag-cake', 'raspberri'], dtype=object),
#  array([133, '4th-of-july-flag-cake', 'blueberri'], dtype=object),
#  array([133, '4th-of-july-flag-cake', 'cream chees'], dtype=object),
#  array([133, '4th-of-july-flag-cake', 'milk'], dtype=object),
#  array([133, '4th-of-july-flag-cake', 'whipped top'], dtype=object),
#  array([134, '4th-of-july-frozen-yogurt-bites', 'blueberri'], dtype=object),
#  array([134, '4th-of-july-frozen-yogurt-bites', 'strawberri'], dtype=object),
#  array([134, '4th-of-july-frozen-yogurt-bites', 'yogurt'], dtype=object),
#  array([135, '4th-of-july-fruit-kabobs', 'watermelon'], dtype=object),
#  array([135, '4th-of-july-fruit-kabobs', 'wooden skew'], dtype=object),
#  array([135, '4th-of-july-fruit-kabobs', 'blueberri'], dtype=object),
#  array([136, '4th-of-july-fruit-salad', 'blueberri'], dtype=object),
#  array([136, '4th-of-july-fruit-salad', 'watermelon'], dtype=object),
#  array([136, '4th-of-july-fruit-salad', 'cantaloup'], dtype=object),
#  array([136, '4th-of-july-fruit-salad', 'strawberri'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'pork butt'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'garlic'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'brown sugar'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'vegetable oil'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'cumin'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'white sugar'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'dry mustard'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'ginger'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'paprika'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'black pepp'], dtype=object),
#  array([137, '4th-of-july-pulled-pork', 'creole season'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'vegetable oil'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'chocolate cak'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'strawberri'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'egg'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'blueberri'], dtype=object),
#  array([138, '4th-of-july-star-cupcakes', 'water'], dtype=object),
#  array([139, '5-cup-salad', 'marshmallow'], dtype=object),
#  array([139, '5-cup-salad', 'coconut'], dtype=object),
#  array([139, '5-cup-salad', 'sour cream'], dtype=object),
#  array([139, '5-cup-salad', 'pineappl'], dtype=object),
#  array([140, '5-hour-beef-stew', 'tapioca flour'], dtype=object),
#  array([140, '5-hour-beef-stew', 'onion'], dtype=object),
#  array([140, '5-hour-beef-stew', 'cocktail'], dtype=object),
#  array([140, '5-hour-beef-stew', 'carrot'], dtype=object),
#  array([140, '5-hour-beef-stew', 'white sugar'], dtype=object),
#  array([140, '5-hour-beef-stew', 'celeri'], dtype=object),
#  array([140, '5-hour-beef-stew', 'beef tenderloin'], dtype=object),
#  array([140, '5-hour-beef-stew', 'potato'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'water'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'celeri'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'potato'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'garlic'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'carrot'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'onion'], dtype=object),
#  array([141, '5-hour-oven-beef-stew', 'mushroom soup'], dtype=object),
#  array([142, '5-ingredient-crab-salad', 'imitation crabmeat'], dtype=object),
#  array([142, '5-ingredient-crab-salad', 'mayonnais'], dtype=object),
#  array([142, '5-ingredient-crab-salad', 'green pepp'], dtype=object),
#  array([142, '5-ingredient-crab-salad', 'butter'], dtype=object),
#  array([142, '5-ingredient-crab-salad', 'onion'], dtype=object),
#  array([143, '5-ingredient-easy-chocolate-chip-cookies', 'chocolate chip'],
#        dtype=object),
#  array([143, '5-ingredient-easy-chocolate-chip-cookies', 'brown sugar'],
#        dtype=object),
#  array([143, '5-ingredient-easy-chocolate-chip-cookies', 'egg'],
#        dtype=object),
#  array([143, '5-ingredient-easy-chocolate-chip-cookies',
#         'all purpose flour'], dtype=object),
#  array([143, '5-ingredient-easy-chocolate-chip-cookies', 'butter'],
#        dtype=object),
#  array([144, '5-ingredient-flat-iron-steak-marinade',
#         'worcestershire sauc'], dtype=object),
#  array([144, '5-ingredient-flat-iron-steak-marinade', 'onion'],
#        dtype=object),
#  array([144, '5-ingredient-flat-iron-steak-marinade', 'garlic'],
#        dtype=object),
#  array([145, '5-ingredient-keto-and-vegan-chocolate-almond-balls',
#         'chocolate chip'], dtype=object),
#  array([145, '5-ingredient-keto-and-vegan-chocolate-almond-balls',
#         'almond m'], dtype=object),
#  array([145, '5-ingredient-keto-and-vegan-chocolate-almond-balls',
#         'almond biscotti'], dtype=object),
#  array([145, '5-ingredient-keto-and-vegan-chocolate-almond-balls',
#         'almond'], dtype=object),
#  array([145, '5-ingredient-keto-and-vegan-chocolate-almond-balls',
#         'vanilla extract'], dtype=object),
#  array([146, '5-ingredient-key-lime-pie', 'egg'], dtype=object),
#  array([146, '5-ingredient-key-lime-pie', 'milk'], dtype=object),
#  array([146, '5-ingredient-key-lime-pie', 'unsalted butt'], dtype=object),
#  array([146, '5-ingredient-key-lime-pie', 'lemon juic'], dtype=object),
#  array([146, '5-ingredient-key-lime-pie', 'graham crack'], dtype=object),
#  array([147, '5-ingredient-mango-relish', 'tomato'], dtype=object),
#  array([147, '5-ingredient-mango-relish', 'onion'], dtype=object),
#  array([147, '5-ingredient-mango-relish', 'cilantro'], dtype=object),
#  array([148, '5-ingredient-marinated-steak-tips', 'cranberry juic'],
#        dtype=object),
#  array([148, '5-ingredient-marinated-steak-tips', 'italian dress'],
#        dtype=object),
#  array([148, '5-ingredient-marinated-steak-tips', 'ketchup'], dtype=object),
#  array([148, '5-ingredient-marinated-steak-tips', 'carbonated beverag'],
#        dtype=object),
#  array([149, '5-ingredient-mexican-casserole', 'flour tortilla'],
#        dtype=object),
#  array([149, '5-ingredient-mexican-casserole', 'salsa'], dtype=object),
#  array([149, '5-ingredient-mexican-casserole', 'onion'], dtype=object),
#  array([149, '5-ingredient-mexican-casserole', 'chees'], dtype=object),
#  array([149, '5-ingredient-mexican-casserole', 'bean'], dtype=object),
#  array([150, '5-ingredient-mock-cherry-pie', 'water'], dtype=object),
#  array([150, '5-ingredient-mock-cherry-pie', 'dried cranberri'],
#        dtype=object),
#  array([150, '5-ingredient-mock-cherry-pie', 'raisin'], dtype=object),
#  array([150, '5-ingredient-mock-cherry-pie', 'white sugar'], dtype=object),
#  array([150, '5-ingredient-mock-cherry-pie', 'crust'], dtype=object),
#  array([151, '5-ingredient-no-bake-cheesecake', 'cream chees'],
#        dtype=object),
#  array([151, '5-ingredient-no-bake-cheesecake', 'lemon juic'], dtype=object),
#  array([151, '5-ingredient-no-bake-cheesecake', 'graham cracker crust'],
#        dtype=object),
#  array([151, '5-ingredient-no-bake-cheesecake', 'whipped top'],
#        dtype=object),
#  array([151, '5-ingredient-no-bake-cheesecake', 'milk'], dtype=object),
#  array([152, '5-ingredient-peanut-butter-chocolate-cookies', 'butter'],
#        dtype=object),
#  array([152, '5-ingredient-peanut-butter-chocolate-cookies', 'cocoa powd'],
#        dtype=object),
#  array([152, '5-ingredient-peanut-butter-chocolate-cookies', 'egg'],
#        dtype=object),
#  array([152, '5-ingredient-peanut-butter-chocolate-cookies',
#         'vanilla extract'], dtype=object),
#  array([153, '5-ingredient-peppermint-bark', 'candi'], dtype=object),
#  array([153, '5-ingredient-peppermint-bark', 'chocol'], dtype=object),
#  array([153, '5-ingredient-peppermint-bark', 'peppermint extract'],
#        dtype=object),
#  array([153, '5-ingredient-peppermint-bark', 'white chocol'], dtype=object),
#  array([153, '5-ingredient-peppermint-bark', 'canola oil'], dtype=object),
#  array([154, '5-ingredient-smores-pie', 'milk'], dtype=object),
#  array([154, '5-ingredient-smores-pie', 'graham cracker crust'],
#        dtype=object),
#  array([154, '5-ingredient-smores-pie', 'marshmallow'], dtype=object),
#  array([154, '5-ingredient-smores-pie', 'whipped top'], dtype=object),
#  array([154, '5-ingredient-smores-pie', 'chocolate pud'], dtype=object),
#  array([155, '5-ingredient-tiramisu', 'espresso'], dtype=object),
#  array([155, '5-ingredient-tiramisu', 'mascarpone chees'], dtype=object),
#  array([155, '5-ingredient-tiramisu', 'white sugar'], dtype=object),
#  array([155, '5-ingredient-tiramisu', 'heavy whipping cream'], dtype=object),
#  array([156, '5-ingredient-tortellini-salad', 'soy sauc'], dtype=object),
#  array([156, '5-ingredient-tortellini-salad', 'black ol'], dtype=object),
#  array([156, '5-ingredient-tortellini-salad', 'mayonnais'], dtype=object),
#  array([156, '5-ingredient-tortellini-salad', 'tomato'], dtype=object),
#  array([157, '5-ingredient-vegetarian-chili', 'olive oil'], dtype=object),
#  array([157, '5-ingredient-vegetarian-chili', 'tomato'], dtype=object),
#  array([157, '5-ingredient-vegetarian-chili', 'chili powd'], dtype=object),
#  array([157, '5-ingredient-vegetarian-chili', 'black pepp'], dtype=object),
#  array([157, '5-ingredient-vegetarian-chili', 'onion'], dtype=object),
#  array([158, '5-ingredient-white-chicken-chili', 'chicken broth'],
#        dtype=object),
#  array([158, '5-ingredient-white-chicken-chili', 'bean'], dtype=object),
#  array([158, '5-ingredient-white-chicken-chili', 'onion'], dtype=object),
#  array([158, '5-ingredient-white-chicken-chili', 'chicken'], dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'sugar'], dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'brown sugar'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'chocol'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'milk'], dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'banana'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'unsalted butt'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'vanilla pud'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie',
#         'heavy whipping cream'], dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'cream chees'],
#        dtype=object),
#  array([159, '5-layer-chocolate-banana-pudding-pie', 'pretzel'],
#        dtype=object),
#  array([160, '5-layer-mexican-dip', 'guacamol'], dtype=object),
#  array([160, '5-layer-mexican-dip', 'bean'], dtype=object),
#  array([160, '5-layer-mexican-dip', 'sour cream'], dtype=object),
#  array([160, '5-layer-mexican-dip', 'cheddar chees'], dtype=object),
#  array([160, '5-layer-mexican-dip', 'tomato'], dtype=object),
#  array([161, '5-minute-banana-berry-smoothie', 'strawberri'], dtype=object),
#  array([161, '5-minute-banana-berry-smoothie', 'banana'], dtype=object),
#  array([161, '5-minute-banana-berry-smoothie', 'orange juic'], dtype=object),
#  array([161, '5-minute-banana-berry-smoothie', 'honey'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'white sugar'],
#        dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'shallot'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'thyme'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'tomato'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'oregano'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'olive oil'],
#        dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'basil'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'salt'], dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'baking soda'],
#        dtype=object),
#  array([162, '5-minute-bulk-blender-pizza-sauce', 'garlic'], dtype=object),
#  array([163, '5-minute-cookies', 'butter'], dtype=object),
#  array([163, '5-minute-cookies', 'cocoa powd'], dtype=object),
#  array([163, '5-minute-cookies', 'white sugar'], dtype=object),
#  array([163, '5-minute-cookies', 'milk'], dtype=object),
#  array([163, '5-minute-cookies', 'coconut'], dtype=object),
#  array([163, '5-minute-cookies', 'oat'], dtype=object),
#  array([163, '5-minute-cookies', 'vanilla extract'], dtype=object),
#  array([164, '5-minute-creamy-keto-cucumber-salad', 'cucumb'], dtype=object),
#  array([164, '5-minute-creamy-keto-cucumber-salad', 'salt'], dtype=object),
#  array([164, '5-minute-creamy-keto-cucumber-salad', 'mayonnais'],
#        dtype=object),
#  array([164, '5-minute-creamy-keto-cucumber-salad', 'black pepp'],
#        dtype=object),
#  array([164, '5-minute-creamy-keto-cucumber-salad', 'lemon juic'],
#        dtype=object),
#  array([165, '5-minute-guacamole', 'cherry tomato'], dtype=object),
#  array([165, '5-minute-guacamole', 'avocado'], dtype=object),
#  array([165, '5-minute-guacamole', 'onion'], dtype=object),
#  array([165, '5-minute-guacamole', 'garlic'], dtype=object),
#  array([166, '5-minute-holiday-nog-egg-free-dairy-free-sugar-free',
#         'nutmeg'], dtype=object),
#  array([166, '5-minute-holiday-nog-egg-free-dairy-free-sugar-free', 'milk'],
#        dtype=object),
#  array([166, '5-minute-holiday-nog-egg-free-dairy-free-sugar-free',
#         'agave nectar'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'white sugar'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'all purpose flour'],
#        dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'vegetable oil'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'salt'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'milk'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'cornmeal'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'baking powd'], dtype=object),
#  array([167, '5-minute-microwave-cornbread', 'egg'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'white sugar'],
#        dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'salt'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake',
#         'chocolate-hazelnut spread'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'vanilla extract'],
#        dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'cocoa powd'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'milk'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'flour'], dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'vegetable oil'],
#        dtype=object),
#  array([168, '5-minute-microwave-nutella-cake', 'egg'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'parsley'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'olive oil'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'garlic'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'basil'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'black pepp'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'salt'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'garbanzo bean'], dtype=object),
#  array([169, '5-minute-olive-hummus', 'lemon juic'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'salt'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'parsley'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'caper'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'oregano'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'black pepp'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'garlic'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'green onion'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'lemon juic'], dtype=object),
#  array([170, '5-minute-olive-tapenade', 'olive oil'], dtype=object),
#  array([171, '5-minute-slaw', 'onion'], dtype=object),
#  array([171, '5-minute-slaw', 'celery se'], dtype=object),
#  array([171, '5-minute-slaw', 'salt'], dtype=object),
#  array([171, '5-minute-slaw', 'white vinegar'], dtype=object),
#  array([171, '5-minute-slaw', 'white sugar'], dtype=object),
#  ...]
